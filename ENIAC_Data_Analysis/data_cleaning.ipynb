# %% [markdown]
# # Data Cleaning with Pandas
#
# In this notebook we'll go through a few basic data cleaning steps that should be performed on all new datasets where necessary.
#
# We'll go through the process with both the `orders` and `orderlines` datasets. You can then practice these skills by cleaning the `products` dataset yourself

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None) # to increase the width of the columns

# %%
# orders.csv
url = "https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path)

# orderlines.csv
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines = pd.read_csv(path)

# %% [markdown]
# Before we begin, let's create a copy of the `orders` and `orderlines` DataFrames. This way we are sure any of our changes won't affect the original DataFrames.

# %%
orders_df = orders.copy()

# %%
orderlines_df = orderlines.copy()

# %% [markdown]
# One of the best ways to begin data cleaning is by exploring using `.info()`. This will tell us:
# * The shape of the DataFrame
# * The names of the columns
# * If there are any missing values
# * The datatypes of the columns
#
# By exploring the missing values and correcting any incorrect datatypes, we often come across inconsistencies in our data.
#
# Beyond this, we should also have a **check for any duplicate rows**.
#
# Let's first deal with the duplicates, as it's nice and easy, then we'll explore what `.info()` has to tell us.

# %% [markdown]
# ## 1.&nbsp; Duplicates
# We can check for duplicates using the pandas [.duplicated()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html) method.
#
# We can then delete these rows, if we wish, using [.drop_duplicates()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html)

# %%
# orders
orders_df.duplicated().sum()
# Out:
# 0

# %%
# orderlines
orderlines_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We have no duplicate rows in either DataFrame. Easy, there is no problem to solve. Normally though, if there were some duplicates, we'd drop the extra rows.

# %% [markdown]
# # 2.&nbsp; `.info()`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# * `total_paid` has 5 missing values
# * `created_date` should become datetime datatype

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# ## 3.&nbsp; Missing values

# %% [markdown]
# ### 3.1.&nbsp; Orders
# * `total_paid` has 5 missing values

# %%
print(f"5 missing values represents {((orders_df.total_paid.isna().sum() / orders_df.shape[0])*100).round(5)}% of the rows in our DataFrame")
# Out:
# 5 missing values represents 0.0022% of the rows in our DataFrame

# %% [markdown]
# > A quick way to find out a percentage here, if you don't need to print out a sentence for yourself/students/colleagues is `.value_counts(normalize=True)`

# %%
orders_df.total_paid.isna().value_counts(normalize=True)
# Out:
# False    0.999978
# True     0.000022
# Name: total_paid, dtype: float64

# %% [markdown]
# As there is such a tiny amount of missing values, we will simply delete these rows, as we have enough data without them.

# %%
orders_df = orders_df.loc[~orders.total_paid.isna(), :]

# %% [markdown]
# Should you have a significant number of missing values in the future, you have a choice:
# + you can impute the values
# + you can take the values from other DataFrames, if they are present there
# + you can delete the values
# + or any number of other creative solutions
#
# Please, always consider how much time you have on your project, and what impact your method of choice will have on your final assesment.

# %% [markdown]
# ### 3.2.&nbsp; Orderlines
# There are no missing values in `orderlines`

# %% [markdown]
# ## 4.&nbsp; Datatypes

# %% [markdown]
# ### 4.1.&nbsp; Orders
# * `created_date` should become datetime datatype

# %%
orders_df["created_date"] = pd.to_datetime(orders_df["created_date"])

# %% [markdown]
# ### 4.1.&nbsp; Orderlines
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# #### 4.1.1.&nbsp; `date`

# %%
orderlines_df["date"] = pd.to_datetime(orderlines_df["date"])

# %% [markdown]
# #### 4.1.2.&nbsp;`unit_price`

# %%
orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-ddce6c16f698> in <cell line: 1>()
# ----> 1 orderlines["unit_price"] = pd.to_numeric(orderlines["unit_price"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99" at position 6

# %% [markdown]
# As you can see when we try to convert `unit_price` to a numerical datatype, we receive a `ValueError` telling us that pandas doesn't understand the number `1.137.99`. This is probably because numbers cannot have 2 decimal points. Let's see if there are any other numbers like this.

# %%
orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+").value_counts()
# Out:
# False    257814
# True      36169
# Name: unit_price, dtype: int64

# %% [markdown]
# Looks like over 36000 rows in `orderlines` are affected by this problem. Let's work out how much that is as a percentage of our total data.

# %%
two_dot_percentage = ((orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+").value_counts()[1] / orderlines_df.shape[0])*100).round(2)
print(f"The 2 dot problem represents {two_dot_percentage}% of the rows in our DataFrame")
# Out:
# The 2 dot problem represents 12.3% of the rows in our DataFrame

# %% [markdown]
# This is a bit of a tricky decision as 12.3% is a significant amount of our data... and we might even end up losing a larger portion of our data than this too. For the moment we will delete the rows as we only have 2 weeks for this project and I'd like some quick, accurate results to show. If we have time at the end, we can come back and investigate this problem further, maybe there's a solution?
#
# Each row of `orderlines` represents a product in an order. For example, if order number 175 contained 3 seperate products, then order 175 would have 3 rows in `orderlines`, one row for each of the products. If 2 of those products have 'normal' prices (14.99, 15.85) and 1 has a price with 2 decimal points (1.137.99), we need to remove the whole order and not just the affected row. If we only remove the row with 2 decimal places then any later analysis about products and prices could be misleading.
#
# We therefore need to find the order numbers associated with the rows that have 2 decimal points, and then remove all the associated rows.

# %%
two_dot_order_ids_list = orderlines_df.loc[orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+"), "id_order"]

orderlines_df = orderlines_df.loc[~orderlines_df.id_order.isin(two_dot_order_ids_list)]

# %%
orderlines_df.shape[0]
# Out:
# 216250

# %% [markdown]
# We still have 216250 rows in orderlines to work with. This should be more than enough for our evaluation.
#
# Now that all of the 2 decimal point prices have been removed, let's try again to convert the column `unit_price` to the correct datatype.

# %%
orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])

# %% [markdown]
# It worked perfectly

# %% [markdown]
# # Challenge: Clean the `products` DataFrame
# Now it's your turn. Use the lessons you learnt above and clean the products DataFrame. You don't have to copy exactly what we did. Think about the consequences of your actions, sometimes it is ok to delete rows, other times you may wish to come up with more creative solutions.

# %%
import pandas as pd

# %%
# products.csv
url = "https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# %%
products_df = products.copy()

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# We'll go through the steps above in order
# * Duplicates
# * Missing values
# * Datatypes
#
# But I think we can all see straight away from `products.head()` above that some of the prices in `promo_price` look wrong. Let's make sure we deal with this later.

# %% [markdown]
# ## Duplicates

# %%
products_df.duplicated().sum()
# Out:
# np.int64(8746)

# %% [markdown]
# Wow, that's a lot of duplicates. Let's get rid of them.

# %%
products_df = products_df.drop_duplicates()

# %%
products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
products_df[products_df["sku"].duplicated(keep=False)]
# Out:
#           sku                                                           name  \
# 7992  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display 4K | 8GB | 1TB
# 8000  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display 4K | 8GB | 1TB
#
#                                                                                     desc  \
# 7992  Desktop Apple iMac 21.5 inch i5 31 GHz Retina display 4K RAM 8GB 1TB (MK452Y / A).
# 8000  Desktop Apple iMac 21.5 inch i5 31 GHz Retina display 4K RAM 8GB 1TB (MK452Y / A).
#
#      price promo_price  in_stock  type
# 7992  1729     1305.59         0  1282
# 8000   NaN     1305.59         0  1282

# %%
pd.set_option('display.max_colwidth', None) # to increase the width of the columns

# %% [markdown]
# ## `.info()`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10573 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  int64
#  6   type         10530 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 661.2+ KB

# %% [markdown]
# ### Missing values
# We can see from `.info()` above that we have missing values in `desc` and `price`

# %% [markdown]
# #### `desc`

# %%
products_df["desc"].isna().sum()
# Out:
# np.int64(7)

# %% [markdown]
# 7 is a very small number to have missing, let's have a closer look

# %%
products_df.loc[products_df['desc'].isna(), :]
# Out:
#              sku  \
# 16126  WDT0211-A
# 16128  APP1622-A
# 17843    PAC2334
# 18152  KAN0034-A
# 18490    HTE0025
# 18612    OTT0200
# 18690  HOW0001-A
#
#                                                                                 name  \
# 16126                    Open - Purple 2TB WD 35 "PC Security Mac hard drive and NAS
# 16128                      Open - Apple Smart Keyboard Pro Keyboard Folio iPad 9.7 "
# 17843                                         Synology DS718 + NAS Server | 10GB RAM
# 18152                       Open - Kanex USB-C Gigabit Ethernet Adapter MacBook 12 "
# 18490                    Hyper Pearl 1600mAh battery Mini USB Mirror and Comic Blond
# 18612                                OtterBox External Battery Power Pack 20000 mAHr
# 18690  Open - Honeywell thermostat Lyric zonificador T6 Intelligent Wireless (cable)
#
#       desc      price promo_price  in_stock      type
# 16126  NaN        107     814.659         0      1298
# 16128  NaN  1.568.206   1.568.206         0      1298
# 17843  NaN     566.35   5.659.896         0  12175397
# 18152  NaN      29.99     237.925         0      1298
# 18490  NaN      24.99       22.99         1      1515
# 18612  NaN      79.99       56.99         1      1515
# 18690  NaN     199.99   1.441.174         0  11905404

# %% [markdown]
# We have 2 choices here:
# * We can quickly and easily remove these rows.
# * Or, alternatively, the products names here are quite descriptive, so I'm tempted to just copy them to the description column, so that there is a description if we later want to utilise this column. I wouldn't recommend this if this DataFrame was the source of truth for our website. But this is not the case here, and we're not faking any information (guessing a price or so), so I'm happy with this option

# %%
products_df.loc[products_df['desc'].isna(), 'desc'] = products_df.loc[products_df['desc'].isna(), 'name']

# %%
products_df.loc[products_df['desc'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [sku, name, desc, price, promo_price, in_stock, type]
# Index: []

# %% [markdown]
# Did you also notice above that we have the dreaded two decimal point problem in both the `price` and `promo_price` columns? We can also see prices with 3 decimal places, prices should have 2 decimal places: this gives us more cause for concern

# %% [markdown]
# #### `price`

# %%
products_df.price.isna().sum()
# Out:
# np.int64(46)

# %%
products_df.price.isna().value_counts(normalize=True).iloc[1]
# Out:
# np.float64(0.004347826086956522)

# %%
print(f"The missing values in price are {(products_df.price.isna().value_counts(normalize=True).iloc[1] * 100).round(2)}% of all rows in the DataFrame")
# Out:
# The missing values in price are 0.43% of all rows in the DataFrame

# %% [markdown]
# Let's simply delete these rows to ensure that we can trust the numbers in our final DataFrame. Afterall, the price is very important when investigating discounts.

# %% [markdown]
# Option 1: `.loc`

# %%
products_df = products_df.loc[~products['price'].isna()]

# %% [markdown]
# Option 2: `.dropna()`

# %%
# products_df = products_df.dropna(subset=['price'])

# %% [markdown]
# #### `type`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10534 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10534 non-null  object
#  1   name         10534 non-null  object
#  2   desc         10534 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10534 non-null  object
#  5   in_stock     10534 non-null  int64
#  6   type         10484 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 658.4+ KB

# %% [markdown]
# Type isn’t an essential piece of data for the analysis and is therefore allowed to carry missing values.
# The only place it comes in later is as an optional route to category creation, where someone might still choose to drop the rows with missing values, however one can still use name and desc to categorize those rows.

# %% [markdown]
# ### Data types
#
# We saw from looking at the output of `.info()` that both `price` and `promo_price` have been stored as objects and not as a numerical datatypes. We also saw while solving other problems that both columns have some prices with 3 decimal places and others with 2 decimal points - the latter will prevent us from converting the datatype to numerical, so first we must investigate and solve these problems.

# %% [markdown]
# #### `price`

# %% [markdown]
# First, let's see how many values are affected by the 2-decimal-dot problems or 3 decimal places.

# %%
products_df.loc[(products_df.price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.price.str.contains(r"\d+\.\d{3,}")), :]
# Out:
#            sku                                                    name  \
# 362    REP0043                           Speaker lower repair iPhone 4
# 480    PIE0011                          Internal Battery for iPhone 3G
# 515    SEN0061  Sennheiser EZX 80 Handsfree iPhone iPad and iPod black
# 518    SEV0026      Service installation RAM + HDD + SSD MacBook / Pro
# 525    SEV0024           Service installation RAM + HDD + SSD Mac mini
# ...        ...                                                     ...
# 19312  REP0424                            Input repair Headphones iPad
# 19313  REP0421                          iPad charging connector repair
# 19314  REP0416                                iPad front camera repair
# 19315  REP0413                                 repair rear camera iPad
# 19316  REP0407                                     iPad battery repair
#
#                                                                       desc  \
# 362                  Repair service including parts and labor for iPhone 4
# 480                            Replacement AC Adapter for Apple iPhone 3G.
# 515                IPhone bluetooth headset with microphone iPad and iPod.
# 518    RAM + HDD installation + SSD in your MacBook / Pro + Data Transfer.
# 525         installation RAM HDD + SSD + on your Mac mini + Data Transfer.
# ...                                                                    ...
# 19312                    Repair service including parts and labor for iPad
# 19313                    Repair service including parts and labor for iPad
# 19314                    Repair service including parts and labor for iPad
# 19315                    Repair service including parts and labor for iPad
# 19316                    Repair service including parts and labor for iPad
#
#            price promo_price  in_stock      type
# 362      499.004     499.004         0  1,44E+11
# 480       98.978      98.978         0  21485407
# 515      649.891     649.891         0      5384
# 518      599.918     599.918         0  20642062
# 525      599.918     599.918         0  20642062
# ...          ...         ...       ...       ...
# 19312  6.999.003       69.99         0  1,44E+11
# 19313  6.999.003       69.99         0  1,44E+11
# 19314  6.999.003       69.99         0  1,44E+11
# 19315  6.999.003       69.99         0  1,44E+11
# 19316  6.999.003       69.99         0  1,44E+11
#
# [542 rows x 7 columns]

# %%
products_df.loc[(products_df.price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.price.str.contains(r"\d+\.\d{3,}")), :].shape#[0]
# Out:
# (542, 7)

# %%
price_problems_number = products_df.loc[(products_df.price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.price.str.contains(r"\d+\.\d{3,}")), :].shape[0]
price_problems_number
# Out:
# 542

# %%
print(f"The column price has in total {price_problems_number} wrong values. This is {round(((price_problems_number / products_df.shape[0]) * 100), 2)}% of the rows of the DataFrame")
# Out:
# The column price has in total 542 wrong values. This is 5.15% of the rows of the DataFrame

# %% [markdown]
# 5.15% is a reasonable amount of our data. However, the price column will be important to understanding discounts, so I'd like it to be very trustworthy as we are basing business decisions on it. Therefore, we'll delete these rows

# %%
products_df = products_df.loc[~((products_df.price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.price.str.contains(r"\d+\.\d{3,}"))), :]

# %%
products_df.sample(50)
# Out:
#              sku  \
# 15083  WAC0170-A
# 17864    PAC2232
# 12794  OWC0020-A
# 14570    SAT0020
# 12144    NOM0017
# 1889     RUT0024
# 10737    ICA0056
# 2529     FCM0020
# 14476    LAC0222
# 13351    APP1650
# 17989    PAC2284
# 11712    CAI0007
# 12132    UAG0038
# 3057     DLL0020
# 11000    PAC1307
# 1869     PAC0623
# 15678    HOC0016
# 11848    BOS0033
# 18316    NOM0029
# 1462     PAC0566
# 18091    PAC2293
# 1457     PAC0560
# 16853    GLY0013
# 18322    EVU0017
# 1252     PUR0122
# 18378    BOD0008
# 13627    IFX0110
# 15512  LAC0204-A
# 18818  HTE0007-A
# 18677  WDT0366-A
# 12459    PAC1414
# 1180     MUV0141
# 14507  TRA0020-A
# 11490    TWS0093
# 17404    COR0008
# 13560    APP1703
# 17988    PAC2283
# 2616     NUD0007
# 11304    PAC1347
# 12586    IFX0077
# 13738  GRT0435-A
# 12277    LEX0036
# 13122    SAN0147
# 17677  BEL0285-A
# 5784     PAC1058
# 1382     APP1938
# 18420    APP2651
# 905      NEA0008
# 19029    PAC2505
# 13531    APP1760
#
#                                                                                                  name  \
# 15083                                                 Open - Wacom Bamboo Spark snap-fit ​​iPad Air 2
# 17864                                      Synology DS218 + NAS Server | 6GB RAM | 6TB (2x3TB) WD Red
# 12794                                  (Open) Installation Kit OWC SSD / HDD 25 "Mac mini (2011/2012)
# 14570                         Satechi Aluminum Card Reader USB-C to USB 3.0 / Micro SD Silver for Mac
# 12144                                                                Nomad Key Chain Lightning to USB
# 1889                                                              Touchscreens Runtastic gloves M / L
# 10737                                                Incase Systm Smart Case Cover iPhone 6 / 6S Gray
# 2529                                                           FCM Mac Memory 1GB 667MHz DDR2 SO-DIMM
# 14476                                             96TB 12big LaCie Hard Disk Thunderbolt RAID 3 USB-C
# 13351                                                                       Apple iPhone 7 128GB Gold
# 17989                              Second hand - Apple iMac 215 "Core i3 306GHz | 4GB RAM | 500GB HDD
# 11712                                                 Casetify White Paisley Case iPhone 6 / 6S Print
# 12132                                                Urban Armor Gear Case iPhone 5S / SE Ash / Black
# 3057                                                         Monitor Dell S2715H 27 "FHD IPS HDMI VGA
# 11000                                             Pack QNAP TS-451 + | 8GB RAM + 8TB Seagate IronWolf
# 1869                 Samsung SSD 850 expansion kit EVO 500GB + OWC Mount Pro for Mac Pro 2009 to 2012
# 15678                                               Hoco Milanese Apple Watch Edition 42mm Black Belt
# 11848                                                      Bose Headphones SoundSport IE IFM Ice Gray
# 18316                                                    Nomad iPhone Case X Clear Case brown leather
# 1462                                           Samsung SSD 850 expansion kit PRO 256GB iMac 215 "2011
# 18091                                              DS218play Synology NAS Server | 4TB (2x2TB) WD Red
# 1457          Samsung SSD 850 expansion kit 1TB PRO + Datadoubler iMac Mac mini 2009 and 2009 to 2011
# 16853                                      Glyph StudioRAID 7200rpm HDD RAID 8TB Thunderbolt System 2
# 18322                             Evutec Aergo Ballistic Nylon Case + X iPhone Support Handsfree Blue
# 1252                                                      Puro Booklet Cover iPhone 6 / 6S Plus Black
# 18378                   Pro TrainR BodyGuardz iPhone Case with Armband 8 Plus / 7 Plus / 6 Plus Black
# 13627                                                             iFixit piece Vibrator iPhone 5 / 5S
# 15512                                                             Open - 8TB LaCie 2big Thunderbolt 2
# 18818                                      Open - Hyperdrive DUO USB Hub Thunderbolt-C 3 Spatial Gray
# 18677                                            Open - 4TB WD My Book External Hard Drive 35 USB 3.0
# 12459                                             Synology DS716 + II Pack | 8GB RAM | WD 4TB Network
# 1180                                                                   Muvit Slim Folio iPhone 6 Pink
# 14507  Open - Kit Transcend JetDrive expansion SSD 725 240GB Retina Macbook Pro 15 "from 2012 to 2013
# 11490                                     Twelve South BookArc support for MacBook Pro / Air / Retina
# 17404                                                           Corning Optical Thunderbolt Cable 10m
# 13560                            Apple Watch Series 2 38mm Silver Aluminum Case and Strap Sport White
# 17988                              Second hand - Apple iMac 215 "Core i3 306GHz | 4GB RAM | 500GB HDD
# 2616                                                                  Nude Audio speaker S Move Coral
# 11304                                                            Synology DS216 Pack | WD 4TB Network
# 12586                                                                   iFixit iPhone Speaker 6 Piece
# 13738                              (Open) iPhone Case Griffin Survivor Summit 7 Black / Black / Black
# 12277                                                 Lexar Lightning adapter for microSD Card Reader
# 13122                                                    Pendrive 32GB SanDisk Ultra Dual USB-C / USB
# 17677                              Open - Air Protect SheerForce Case Belkin iPhone 6 / 6S Space Gray
# 5784                       Apple iMac 27 "Core i5 3.3GHz Retina 5K | 32GB | 3TB Fusion | R9 M395X 4GB
# 1382                                 Apple Mac mini Core i5 28GHz | 8GB RAM | 1TB Flash (MGEQ2YP / A)
# 18420             Apple iMac Pro 27 "14-core Intel Xeon W 25GHz | 32GB | 2TB SSD | Radeon Pro Vega 64
# 905                                                                      Netatmo plug weather station
# 19029                            OWC ThuderBay RAID Thunderbolt 4 3 | 40TB (4x10TB) Seagate Iron Wolf
# 13531                                                        Apple iPad mini Smart Cover 4 Blue Ocean
#
#                                                                                                               desc  \
# 15083                                                                                            Bloc Smart notes.
# 17864                                          NAS storage server integrated with special focus on data protection
# 12794                                            Installation kit or SSD hard drive for Mac mini 2011/2012 + tools
# 14570                                  Card reader with SD slots for SD and USB and Micro-C connection and USB 3.0
# 12144                                                              Chain Lightning to USB for iPhone iPad and iPod
# 1889                                                                        Touch gloves for iPhone iPod and iPad.
# 10737                                                                           Double casing layer iPhone 6 / 6s.
# 2529                                                 1GB RAM Mac mini and iMac (2006/07) MacBook Pro (2006/07/08).
# 14476   12 Hard Drive 96TB RAID 5 bays with two ports Thunderbolt 3 (40Gb / s) and 5 years warranty for Mac and PC
# 13351                                                                           New Apple iPhone 7 128GB Free Gold
# 17989                                    Computer Refurbished iMac Core i3 215 inches 306GHz | 4GB RAM | 500GB HDD
# 11712                                                                   Casetify fashion sleeve for iPhone 6 / 6S.
# 12132                                                                         Super durable Case for iPhone 5S & 5
# 3057                 27-inch widescreen monitor angle 21 degrees FHD with free cable and HDMI / MHL for Mac and PC
# 11000  Pack QNAP TS-451 + with 8GB of RAM memory + 8TB (4x2TB) IronWolf Seagate Hard Drive Desktop for Mac and PC.
# 1869                                500GB SSD expansion kit + Adapter Mount Pro for Mac Pro Early 2009 to Mid 2012
# 15678                                                 Stainless steel strap Color Black Hoco for Apple Watch 42 mm
# 11848                                       In-Ear Headphones with earplugs sports parts for iPhone iPad and iPod.
# 18316                                transparent cover with high quality leather with microfiber interior iPhone X
# 1462                                                        Upgrade kit for 256GB SSD 215 inch Mid 2011 iMac tools
# 18091                                                           2-bay NAS server can accommodate 4K Ultra HD files
# 1457      SSD upgrade kit for Mac 1TB + Datadoubler Mini Early / Late 2009 and Mid 2009 iMac Early 2011 with tools
# 16853                              8TB RAID system with free Thunderbolt 2 and 2 HDD 7200rpm drives for Mac and PC
# 18322                                                 Cover with anti-impact nylon plastic and iPhone car holder X
# 1252                                                                            Flip cover for iPhone 6 / 6S Plus.
# 18378                                 Advanced holster included sports armband for iPhone 8 Plus / 7 Plus / 6 Plus
# 13627                                                                      Vibrating piece parts for iPhone 5 / 5S
# 15512             RAID 8TB double disc box designed to work 24x7 Thunderbolt 2 and 5 years warranty for Mac and PC
# 18818     Reconditioned Hub Thunderbolt port 3 HDMI and USB-C ports and two USB 3.1 Micro SDXC SDXC for Mac and PC
# 18677                                      External Hard Drive 4TB refitted with USB 3.0 connection for Mac and PC
# 12459                               Synology DS716 + II with 8GB of RAM memory + 4TB (2x2TB) WD Red for Mac and PC
# 1180                                                      Cover with support function with lid 47 iPhone 6 inches.
# 14507                             240GB SSD expansion for Macbook Pro Retina 15-inch Early 2013 Mid 2012 Kit tools
# 11490                                                               Aluminum support in an arc Retina MacBook Air.
# 17404                                                                           Optical Cable 10-meter thunderbolt
# 13560                          Apple Watch 38 mm with GPS dual-core processor and retina display submersible 50mts
# 17988                                    Computer Refurbished iMac Core i3 215 inches 306GHz | 4GB RAM | 500GB HDD
# 2616                                              Compact Portable Bluetooth speaker with 8 hours of battery life.
# 11304                                         Synology DS216 + Pack 4TB (2x2TB) WD Red hard drives for Mac and PC.
# 12586                                                                                         Speaker for iPhone 6
# 13738                                                hard case with screen protector and clip support for iPhone 7
# 12277                                                                Lightning adapter microSD for iPad and iPhone
# 13122                                  32GB flash drive with two different USB-C and USB connection for Mac and PC
# 17677                                   Cover with compact design and wear resistant material and UV iPhone 6 / 6s
# 5784              IMac desktop computer 27 inch 5K Retina i5 3.3GHz RAM 32GB 3TB Fusion R9 M395X 4GB (MK482Y / A).
# 1382                                     Apple desktop Mac mini Core i5 28GHz | 8GB RAM | 1TB Flash (MGEQ2YP / A).
# 18420                                        Pro iMac 27 inch screen Retina 5K and Intel Xeon processor W of 25GHz
# 905                                      Additional module Netatmo weather station for iPhone iPad and iPod Touch.
# 19029                                      RAID Disk external box 25 inch and 35 inch two connectors Thunderbolt 3
# 13531                                                                         Polyurethane Smart Cover iPad Mini 4
#
#          price promo_price  in_stock       type
# 15083    159.9     789.311         0       1298
# 17864   664.98   6.021.795         1   12175397
# 12794    54.99     215.375         0       1298
# 14570    34.99     249.901         1   12585395
# 12144    24.99     199.904         0       1230
# 1889     19.99     169.884         0   11905404
# 10737    34.95     219.905         0   11865403
# 2529     10.99      99.898         0       1364
# 14476     8199  59.999.943         0   11935397
# 13351      749   7.340.005         0   85641716
# 17989     1199   6.135.945         0   5,72E+15
# 11712    39.95     199.904         0   11865403
# 12132    29.99     199.904         0   12635403
# 3057    347.27   2.729.881         0       1296
# 11000  1039.95   8.983.681         0   12175397
# 1869    215.98   1.595.845         1       1433
# 15678       89       69.99         0       2449
# 11848       99     899.901         0       5384
# 18316    39.95       31.99         0   11865403
# 1462    200.98   1.685.845         0       1433
# 18091   438.99   3.889.896         0   12175397
# 1457    587.98   4.935.844         0       1433
# 16853   787.33   5.539.949         1   11935397
# 18322    29.99     199.904         1   11865403
# 1252     19.99      69.902         0   11865403
# 18378    39.99     279.897         1       5405
# 13627     9.95        9.49         0   21485407
# 15512      569   4.959.821         0   12175397
# 18818    99.95       73.63         0   12585395
# 18677   159.99   1.250.634         0   11935397
# 12459   749.89   7.321.795         0   12175397
# 1180     15.99     124.872         0   11865403
# 14507      245   2.107.533         0       1298
# 11490    59.99     499.899         0       8696
# 17404   302.99   2.999.905         0       1325
# 13560      439   4.390.001         0   24885185
# 17988     1199   6.455.945         0   5,72E+15
# 2616     39.99     349.932         0       5398
# 11304   488.99   4.471.785         0   12175397
# 12586    19.95      79.896         0   21485407
# 13738    44.99     205.716         0       1298
# 12277     37.9     349.896         0   42945397
# 13122    19.99     200.001         1   11935397
# 17677    19.99     159.902         0       1298
# 5784      3769  31.969.894         0   5,74E+15
# 1382      1819  17.100.047         0       1282
# 18420     9099  85.530.048         0  118692158
# 905      69.99     629.926         1   11905404
# 19029  2204.95  16.903.676         1   11935397
# 13531       45     366.303         0   12635403

# %% [markdown]
# To complete our task, let's convert the column to a numeric datatype

# %%
products_df["price"] = pd.to_numeric(products_df["price"])

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9992 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          9992 non-null   object
#  1   name         9992 non-null   object
#  2   desc         9992 non-null   object
#  3   price        9992 non-null   float64
#  4   promo_price  9992 non-null   object
#  5   in_stock     9992 non-null   int64
#  6   type         9946 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 624.5+ KB

# %% [markdown]
# #### `promo_price`

# %% [markdown]
# Again, let's begin by seeing how many values are affected by the 2-decimal-dots problem, or the 3 decimal-places problem

# %%
promo_problems_number = products_df.loc[(products_df.promo_price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.promo_price.str.contains(r"\d+\.\d{3,}")), :].shape[0]
promo_problems_number
# Out:
# 9232

# %%
print(f"The column promo_price has in total {promo_problems_number} wrong values. This is {round(((promo_problems_number / products_df.shape[0]) * 100), 2)}% of the rows of the DataFrame")
# Out:
# The column promo_price has in total 9232 wrong values. This is 92.39% of the rows of the DataFrame

# %% [markdown]
# WOW!!! That's a lot of wrong data. Let's have a quick investigate to check that's correct. We'll make a DataFrame by copy-pasting the code we used above and then look at a large sample to check that all the numbers in the `promo_price` column really have either 2 decimal points or 3 decimal places.

# %%
promo_price_df = products_df.loc[(products_df.promo_price.str.contains(r"\d+\.\d+\.\d+"))|(products_df.promo_price.str.contains(r"\d+\.\d{3,}")), :]
promo_price_df.sample(50)
# Out:
#              sku  \
# 627      NTE0052
# 19009  TUC0302-A
# 11493  OTT0093-A
# 1598     MOS0147
# 17811    PAC2210
# 11308    PAC1349
# 2458     STA0019
# 1076     BLM0019
# 2395     AKG0012
# 16170    PAC2141
# 12356    PAC1429
# 2427   FCM0003-2
# 11742    PAC1377
# 437      BEZ0158
# 17765    PAC2397
# 1378     APP1934
# 17580    APP2501
# 0        RAI0007
# 2546     BTC0015
# 17874    PAC2364
# 18984    AP20448
# 1124     NTE0073
# 12326  UAG0012-A
# 1915     OWC0138
# 68       MAK0009
# 11623    OWC0178
# 2602     DEN0009
# 18791  PHI0073-A
# 19225    WAC0258
# 15844  OWC0124-A
# 16913    APP2166
# 16891    PAC1943
# 474      LMP0011
# 11787    PAC1373
# 13418    APP1697
# 17947    PAC2193
# 91       HGD0015
# 2530   FCM0014-2
# 12499    LGE0040
# 11367    SAN0106
# 12423    PAC1405
# 15220  TRK0005-A
# 725      PAC0366
# 1954     PAC0717
# 16689    APP2413
# 18576    AP20436
# 12756    PAC1866
# 13357    APP1652
# 11351    SAM0093
# 17652  KEN0239-A
#
#                                                                                                         name  \
# 627                                                       NewerTech NuGuard KX iPad Case Mini / Retina Black
# 19009                                          Tucano Nido Hard-Shell Case MacBook Pro 13 "(late 2016) Black
# 11493                                          (Open) Strada OtterBox iPhone Case Leather Folio 6 / 6s Brown
# 1598                                                           SenseCover Moshi Case iPhone 6 / 6S Plus Rosa
# 17811                                            Synology DS718 + NAS Server | 6GB RAM | 16TB (2x8TB) WD Red
# 11308                                                                   Synology DS216 Pack | WD 8TB Network
# 2458                                                 Startech Adapter with Micro Mini-Jack 35mm 2 connectors
# 1076                                                              Blue Microphones Yeti USB Microphone Black
# 2395                                                              AKG Headphones In-Ear Y16 with micro Black
# 16170                                         Apple iMac 27 "Core i5 Retina 5K 35GHz | 64GB RAM | 1TB Fusion
# 12356                                                Synology DS916 + Pack | 8GB RAM | Seagate 12TB IronWolf
# 2427                                                         Mac memory FCM 8GB (2x4GB) SO-DIMM DDR3 1066MHz
# 11742                                                                Pack QNAP TS-228 | Seagate 6TB IronWolf
# 437                                                 Be.ez LArobe Case for MacBook Pro Retina 15 "gray / blue
# 17765                               DS418play Synology NAS Server | 6GB RAM | 24TB (4x6TB) Seagate Iron Wolf
# 1378                                       Apple Mac mini Core i5 28GHz | 16GB RAM | 1TB Flash (MGEQ2YP / A)
# 17580                            Apple Watch GPS 42mm Case Series 3 Aluminum Space Gray and Black Belt Sport
# 0                                                                          Silver Rain Design mStand Support
# 2546                                         Boostcase Hybrid Case & 2000mAh External Battery iPhone 6 Black
# 17874                                 Synology DS218 + NAS Server | 2GB RAM | 16TB (2x8TB) Seagate Iron Wolf
# 18984                                                                  Like new - Apple iPod Touch 16GB Gold
# 1124                                                               NewerTech Lightning to USB Cable Green 1m
# 12326                                  (Open) Urban Armor Gear Composite Case Cover iPhone 6 / 6S Plus White
# 1915                              OWC Mercury Accelsior PCI Express-M M-SATA 6gb / s SSD controller MacPro h
# 68                                                            Maclocks theft case iPad 2 3 and 4 transparent
# 11623                                             OWC USB-C Dock USB 3.1 / HDMI / Audio / GigaEthernet Plata
# 2602                                                               Denon Envaya Mini (DSB 100) Black Speaker
# 18791                                       Open - Philips Hue White and Color Light Bulb 10W A60 E27 Single
# 19225                                   Education - Wacom Intuos Graphics Tablet M Bluetooth Pistachio Green
# 15844                                             Open - OWC HDD Installation Kit for iMac 27 "2012 or later
# 16913                                              Apple iPad Leather Smart Cover Case Pro "Brown Taupe 10.5
# 16891                             Apple Mac Pro 35GHz 6 cores | 32GB RAM | 256GB PCIe SSD | FirePro D700 6GB
# 474                                                      External Slim Case for SuperDrive iMac and Mac mini
# 11787                                                                  Synology Pack DS216J | WD 8TB Network
# 13418                                                           Apple iPhone Leather Case Cover Black Plus 7
# 17947                                                Kit OWC expansion RAM 32GB (2x16GB) DDR4 iMac 215 "2017
# 91                                                              Henge Docks Docking Station MacBook Air 13 "
# 2530                                                          Mac FCM 2GB memory (2x1GB) 667MHz DDR2 SO-DIMM
# 12499                               29UB67-B LG Monitor 29 "HDMI DP tiltable / pivotable / adjustable height
# 11367                                SanDisk Ultra 16GB microSDHC Memory Card + SD Adapter 80MB / s Class 10
# 12423                                                    Synology DS716 + II Pack | 2GB RAM | WD 4TB Network
# 15220                                                        Open - Trackr Bravo Locator Silver Pack 2 units
# 725                                                   Apple Mac Pro six cores 35GHz | 64GB RAM | 256GB Flash
# 1954   Samsung SSD 850 expansion kit EVO 1TB + 8GB RAM 1066Mhz + Datadoubler for iMac and Mac mini 2009 2009
# 16689                                          Apple Macbook 12 "Core i7 14GHz | 16GB | 256GB SSD Space Gray
# 18576                               Like new - Apple iMac 215 "4K Retina Quad Core i5 3.0GHz | 8GB RAM | 1TB
# 12756                                                                Synology DS416play | 8TB (4x2TB) WD Red
# 13357                                                                      Apple iPhone 7 128GB Black Bright
# 11351                                                                         Samsung S22E450F 215 Monitor "
# 17652                        Open - Kensington USB Dock SD1500-C to USB 3.0 / HDMI / VGA / Ethernet Notebook
#
#                                                                                                                                 desc  \
# 627                                                                           IPad mini ultra rugged housing for extreme conditions.
# 19009                                                       Open - Tucano Nido Hard-Shell Case 13-inch MacBook Pro (Late 2016) Black
# 11493                                                                                        Resistant cover card slot for iPhone 6.
# 1598                                                               Cover with touch sensor to answer calls without opening the case.
# 17811                         Scalable NAS server with transcoding 4K: 4-core 2.3 GHz DDR3L 16GB 226MB / s read and 184 MB / s write
# 11308                                                             Pack Synology NAS + 4TB 2 Discs (2x4TB) WD Network for Mac and PC.
# 2458                                                                              Adapter headset jack Mini-4-pin mini-jack 2 3 pin.
# 1076                                               capsules microphone with three and four different pattern settings for Mac and PC
# 2395                                                                             Ear Headphones with Micro for iPhone iPad and iPod.
# 16170                                                           IMac desktop computer 27 inch Retina 5K RAM 64GB (4x16GB) 1TB Fusion
# 12356                              Synology DS916 + with 8GB of RAM memory + 12TB (4x3TB) Seagate Hard Drive for Mac and PC IronWolf
# 2427                                                                RAM 8GB (2x4GB) Mac mini iMac MacBook and MacBook Pro (2009/10).
# 11742                                                                              NAS + 6TB (2x3TB) Seagate IronWolf for Mac and PC
# 437                                                                                  Retina MacBook Pro sleeve 15 inch polyurethane.
# 17765                                                                              4-bay NAS server to accommodate 4K Ultra HD files
# 1378                                                      Apple desktop Mac mini Core i5 28GHz | 16GB RAM | 1TB Flash (MGEQ2YP / A).
# 17580                                                                   42mm Apple Watch series 3 with GPS altimeter and submersible
# 0                                                                                       Aluminum support compatible with all MacBook
# 2546                                                                              Protective housing with built-in iPhone 6 battery.
# 17874                                                            NAS storage server integrated with special focus on data protection
# 18984                                                               6th generation iPod Touch 16GB refitted with 8 megapixel camera.
# 1124                                                            Lightning USB cable 1 meter to charge and sync iPhone iPad and iPod.
# 12326                                                                             resistant cover bumps and drops for iPhone 6 Plus.
# 1915                                                                          PCI Express SSD for Mac Pro up to 5.1 (mid 2010-2012).
# 68                                                                     Case antitheft iPad 2 3 and 4 polycarbonate support and lock.
# 11623                                                                         Dock USB-C multiple connections and SD reader Macbook.
# 2602                                                                 Waterproof Wireless Speaker for iPhone iPad and iPod Bluetooth.
# 18791                                                               Independent bulb color and white for Philips Hue open box system
# 19225                           Medium-edge graphics tablet with Bluetooth integrated and creative software worth 160 euros included
# 15844                                                            installation disc iMac 27-inch HDD in 2012 and later with tools kit
# 16913                                                      Intelligent quality leather case with function on / off 105-inch iPad Pro
# 16891                                               New Mac Pro with 32GB RAM and two 6-core GPU 35GHz AMD FirePro D700 (MD878Y / A)
# 474                                                                                 external enclosure iMac SuperDrive and Mac Mini.
# 11787                                                                                   NAS + 8TB (2x4TB) WD Network for Mac and PC.
# 13418                                                                ultrathin leather case and microfiber premium for iPhone 7 Plus
# 17947                                                                                Tool kit + OWC RAM 32GB DDR4 215 inch iMac 2017
# 91                                                                                          Dock MacBook Air 13-inch multi-function.
# 2530                                                                                       RAM 2GB (2x1GB) Mac with Intel processor.
# 12499                                                           29 ultra widescreen IPS Monitor Dual Link-Up sRGB 99% for Mac and PC
# 11367                                                             MicroSDHC memory card with SD adapter 16 GB with transfer 80MB / s
# 12423                                                 Synology DS716 + II with 2GB of RAM memory + 4TB (2x2TB) WD Red for Mac and PC
# 15220                                                                           2 locators objects with Bluetooth and APP for iPhone
# 725                                                          New Mac Pro with 64GB of RAM 6 Core 2 GPU and 256GB Flash (MD878Y / A).
# 1954   Upgrade kit 1TB SSD + Datadoubler Mac Mini 2009 iMac 20 Early / Mid 2009 iMac 24 Early 2009 iMac 27 inch Late 2009 with tools
# 16689                                                 New MacBook Retina Display 12-inch Core i7 16GB RAM 256GB SSD 14GHz Space Gray
# 18576                                                                            IMac reconditioned 215 inch 4K Retina Quad i5 30GHz
# 12756                                                                     8TB NAS capacity (4x2TB) WD Red hard drives for Mac and PC
# 13357                                                                                     New Apple iPhone 7 128GB Black Free Bright
# 11351                                                                                         Monitor FHD detachable LED 215 inches.
# 17652                                   Refurbished Laptop Dock with 4 ports and 4K video output cable included USB-C for Mac and PC
#
#          price promo_price  in_stock      type
# 627      59.99     279.897         0  12635403
# 19009    29.90     202.898         0  13835403
# 11493    49.99     212.056         0      1298
# 1598     50.00     369.897         0  11865403
# 17811  1239.98  10.011.794         0  12175397
# 11308   628.99   5.501.785         0  12175397
# 2458      9.99       6.989         0      1325
# 1076    149.00   1.399.897         0      1375
# 2395     29.99     259.908         0      5384
# 16170  3979.00  29.670.045         0  5,74E+15
# 12356  1189.16  10.593.683         0  12175397
# 2427     87.98     849.904         0      1364
# 11742   420.97   3.501.788         0  12175397
# 437      34.99     289.916         0  13835403
# 17765  1676.94  12.993.682         0  12175397
# 1378   2059.00  19.350.042         0      1282
# 17580   399.00   3.909.994         1  24895185
# 0        59.99     499.899         1      8696
# 2546     79.99     279.897         0  5,49E+11
# 17874  1064.97   7.791.795         1  12175397
# 18984   229.00   1.689.995         0  11821715
# 1124     29.99     149.895         0      1230
# 12326    34.99     182.774         0      1298
# 1915     60.99     279.873         1      1276
# 68       79.99     799.931         0  12635403
# 11623   217.99   1.799.875         0  12585395
# 2602    129.00     899.901         0      5398
# 18791    59.95     450.444         0  11905404
# 19225   199.00   1.649.896         1      1405
# 15844    72.99     438.896         0      1298
# 16913    85.00     789.997         0  12635403
# 16891  4169.00  38.310.045         0  21632158
# 474      35.00     299.899         0  12995397
# 11787   513.99   4.351.789         0  12175397
# 13418    59.00     490.002         0  11865403
# 17947   475.97   4.369.903         0      1364
# 91       79.99      75.988         1      8696
# 2530     21.98     199.904         0      1364
# 12499   349.00   2.889.988         1      1296
# 11367     5.99      49.888         0  57445397
# 12423   669.90   6.471.794         0  12175397
# 15220    54.99     499.899         0      1298
# 725    6089.00  51.299.898         0      1282
# 1954    605.96   4.605.841         1      1433
# 16689  2039.00  19.170.042         0  5,39E+11
# 18576  1505.59  12.455.946         0      1282
# 12756   830.99     784.368         0  12175397
# 13357   749.00   7.340.005         1  85641716
# 11351   169.99   1.689.898         0      1296
# 17652   105.99     735.935         0      1298

# %% [markdown]
# So we were correct, over 90% of the data in this column is corrupt. There's no point deleting all of these rows, then we would barely have a products table. Instead, as it's only this column that appears to be very untrustworthy, we will delete the column.

# %%
products_cl = products_df.drop(columns=["promo_price"])

# %%
products_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9992 entries, 0 to 19325
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       9992 non-null   object
#  1   name      9992 non-null   object
#  2   desc      9992 non-null   object
#  3   price     9992 non-null   float64
#  4   in_stock  9992 non-null   int64
#  5   type      9946 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 546.4+ KB

# %% [markdown]
# Obviously, there's now no need to convert `promo_price` to a numerical datatype
#
# Don't forget to download/save your new DataFrames. Also, give them an obvious name, so that you know they are the cleaned version and not the original DataFrame.

# %%
from google.colab import files

orders_df.to_csv("orders_cl.csv", index=False)
files.download("orders_cl.csv")

orderlines_df.to_csv("orderlines_cl.csv", index=False)
files.download("orderlines_cl.csv")

products_cl.to_csv("products_cl.csv", index=False)
files.download("products_cl.csv")
